# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai import *
from fastai.vision import *

# %%
path = Path('/storage/lhdata/')
path.ls()
# Out:
# [PosixPath('/storage/lhdata/GFP mf'),
#  PosixPath('/storage/lhdata/saps4 mf'),
#  PosixPath('/storage/lhdata/.DS_Store'),
#  PosixPath('/storage/lhdata/models'),
#  PosixPath('/storage/lhdata/arabdop svp 41- 2'),
#  PosixPath('/storage/lhdata/GFP m'),
#  PosixPath('/storage/lhdata/.git'),
#  PosixPath('/storage/lhdata/arabcolc'),
#  PosixPath('/storage/lhdata/saps4 m')]

# %%
#remove files that won't be identified in each of the data classes
classes = ['GFP mf','saps4 mf','arabdop svp 41- 2', 'GFP m', 'arabcolc', 'saps4 m'  ]
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_workers=8)
# Out:
# GFP mf
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='42' class='' max='42', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [42/42 00:00<00:00]
#     </div>
# saps4 mf
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
# ...

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['GFP m', 'GFP mf', 'arabcolc', 'arabdop svp 41- 2', 'saps4 m', 'saps4 mf']

# %%
#showing a sample batch
data.show_batch(rows=3, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['GFP m', 'GFP mf', 'arabcolc', 'arabdop svp 41- 2', 'saps4 m', 'saps4 mf'],
#  6,
#  287,
#  82)

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(4)
# Out:
# Total time: 00:17
# epoch  train_loss  valid_loss  error_rate
# 1      1.907154    1.532584    0.524390    (00:05)
# 2      1.445176    1.077131    0.402439    (00:04)
# 3      1.173471    0.810883    0.243902    (00:04)
# 4      0.992295    0.667427    0.158537    (00:04)

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(2, max_lr=slice(3e-5,3e-4))
# Out:
# Total time: 00:08
# epoch  train_loss  valid_loss  error_rate
# 1      0.542628    0.449813    0.109756    (00:04)
# 2      0.493396    0.413987    0.097561    (00:04)

# %%
learn.save('stage-2')

# %%
learn.load('stage-2')

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
#plotting a confusion matrix
interp.plot_confusion_matrix()

# %%
from fastai.widgets import *

losses,idxs = interp.top_losses()
top_loss_paths = data.valid_ds.x[idxs]

# %%
fd = FileDeleter(file_paths=top_loss_paths)
# Out:
# ...
# Button(button_style='primary', description='Confirm', style=ButtonStyle())

# %%
#load an rugby image from the data
img = open_image(path/'saps4 mf'/'saps4mf9.png')
img
# Out:
# Image (3, 515, 799)

# %%
# load the model for testing the prediction
classes = ['GFP m', 'GFP mf', 'arabcolc', 'arabdop svp 41- 2', 'saps4 m', 'saps4 mf']
data2 = ImageDataBunch.single_from_classes(path, classes, tfms=get_transforms(), size=224).normalize(imagenet_stats)
learn = create_cnn(data2, models.resnet34)
learn.load('stage-2')

# %%
# predict the test image from the model
pred_class,pred_idx,outputs = learn.predict(img)
pred_class
# Out:
# 'saps4 mf'
